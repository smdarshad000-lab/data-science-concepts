# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
dataset=pd.read_csv('Housing.csv')
x=dataset.iloc[:,1].values.reshape(-1,1)
y=dataset.iloc[:,0].values

# %%
dataset.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
from sklearn.model_selection import train_test_split   
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression
# Out:
# LinearRegression()

# %%
regression.fit(x_train,y_train)
regression
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(x_test)

# %%
# 1. Weight (Slope)
print("Weight (Slope):", regression.coef_)

# 2. Bias (Intercept)
print("Bias (Intercept):", regression.intercept_)
# Out:
# Weight (Slope): [449.44700819]
# Bias (Intercept): 2457461.528387109

# %%
# 3. Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

# 4. Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error (MSE): 3193989923757.6206
# Mean Absolute Error (MAE): 1387227.8956867643

# %%
#visualising the result
plt.scatter(x_test,y_test, color= 'purple')
plt.plot(x_test, regression.predict(x_test), color='blue')
plt.title('House Area vs House Price (Abhilov Gupta)')
plt.xlabel('House Area')
plt.ylabel('House Price')
plt.show()
